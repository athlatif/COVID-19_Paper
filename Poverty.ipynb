# %%
# Assess Poverty to see its effect in cases reporting x

# %%
import numpy as np #importing numpy.
import pandas as pd #importing pandas.
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("occupation_data_UN.csv") 
# Preview the first 5 lines of the loaded data 
df.head()
df['Country or Area'].unique()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# array(['Åland Islands', 'Albania', 'Antigua and Barbuda', 'Armenia',
#        'Aruba', 'Australia', 'Austria', 'Belarus', 'Benin', 'Bermuda',
#        'Bolivia (Plurinational State of)', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Cambodia', 'Canada', 'Cayman Islands', 'China',
#        'China, Hong Kong SAR', 'China, Macao SAR', 'Cook Islands',
#        'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czechia',
#        "Democratic People's Republic of Korea", 'Dominican Republic',
#        'Ecuador', 'Egypt', 'El Salvador', 'Estonia', 'Eswatini',
#        'Finland', 'France', 'French Polynesia', 'Georgia', 'Germany',
#        'Ghana', 'Greece', 'Guam', 'Guinea', 'Hungary', 'Indonesia',
# ...

# %%
Germany = df.loc[df['Country or Area'] == "Germany"]
Germany = Germany.loc[df['Sex'] == "Both Sexes"]
Germany = Germany.loc[df['Age'] == "Total"]

Occupationger = list(Germany['Occupation'])
Valueger = list(Germany['Value'])

Occupationger.pop(len(Valueger)-1)
Valueger.pop(len(Valueger)-1)

print(Occupationger)
print(Valueger)
# Out:
# ['Armed forces occupations (ISCO 08 - 0)', 'Managers (ISCO 08 - 1)', 'Professionals (ISCO 08 - 2)', 'Technicians and associate professionals (ISCO 08 - 3)', 'Clerical support workers (ISCO 08 - 4)', 'Service and sales workers (ISCO 08 - 5)', 'Skilled agricultural, forestry and fishery workers (ISCO 08 - 6)', 'Craft and related trades workers (ISCO 08 - 7)', 'Plant and machine operators, and assemblers (ISCO 08 - 8)', 'Elementary occupations (ISCO 08 - 9)']
# [181030.0, 1976240.0, 6986700.0, 7663850.0, 5434530.0, 6233890.0, 590780.0, 5107070.0, 2631950.0, 3373670.0]

# %%
EssentialGer = []
RemoteGer = [] 

EssentialGer = Valueger[0] + Valueger[6] + Valueger[7] + Valueger[8] + Valueger[9] + Valueger[4]
RemoteGer = Valueger[1] + Valueger[2] + Valueger[3]  + Valueger[5]

# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt



objects = Occupationger
y_pos = np.arange(len(objects))
performance = Valueger

plt.barh(y_pos, np.log10(performance), align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('# number')
plt.title('Germany''s Common Occupations')
plt.xticks([0,1,2,3,4,5,6,7], ['1', '2.7k', '7.3k','20k', '55k', '148k','403k', '1M']) 

plt.show()

# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt



objects = ['Essential Services','Remote-work Amenable Jobs']
y_pos = np.arange(len(objects))
performance = [EssentialGer,RemoteGer]
print(performance)
plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('# number')
plt.title('Remote-work Amenability of Occupations | Germany')


plt.show()
# Out:
# [17319030.0, 22860680.0]

# %%
EssentialGer = []
RemoteGer = []
Valueger = []
oc = []
df = pd.read_csv("occupation_data_UN.csv") 
Germany = df.loc[df['Country or Area'] == "Spain"]

Germany = Germany.loc[df['Sex'] == "Both Sexes"]


Germany = Germany.groupby(['Occupation']).sum().reset_index()

oc = list(Germany['Occupation'])
Valueger = list(Germany['Value'])


EssentialGer = Valueger[1] + Valueger[2] + Valueger[3] + Valueger[4] + Valueger[5] + Valueger[6]  + Valueger[7] + Valueger[8]  
+ Valueger[9]  + Valueger[10] + Valueger[13]  + Valueger[14] + Valueger[15] + Valueger[16]  + Valueger[22]  + Valueger[23]
+ Valueger[24]
RemoteGer = Valueger[0] + Valueger[11] + Valueger[12]  + Valueger[17] + Valueger[18] + Valueger[19] + Valueger[20] +Valueger[25]
+ Valueger[21] + Valueger[26]
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 14885089.0

# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt



objects = ['Essential Services','Remote-work Amenable Jobs']
y_pos = np.arange(len(objects))
performance = [EssentialGer,RemoteGer]
print(performance)
plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('# number')
plt.title('Remote-work Amenability of Occupations | Spain')


plt.show()
# Out:
# [31322261.0, 41814295.0]

# %%
df = pd.read_csv("occupation_data_UN.csv") 
Germany = df.loc[df['Country or Area'] == "Italy"]

Germany = Germany.loc[df['Sex'] == "Both Sexes"]
Germany = Germany.loc[df['Age'] == "Total"]

Occupationger = list(Germany['Occupation'])
Valueger = list(Germany['Value'])

Occupationger.pop(len(Valueger)-1)
Valueger.pop(len(Valueger)-1)

print(Occupationger)
print(Valueger)
# Out:
# ['Armed forces occupations (ISCO 08 - 0)', 'Managers (ISCO 08 - 1)', 'Professionals (ISCO 08 - 2)', 'Technicians and associate professionals (ISCO 08 - 3)', 'Clerical support workers (ISCO 08 - 4)', 'Service and sales workers (ISCO 08 - 5)', 'Skilled agricultural, forestry and fishery workers (ISCO 08 - 6)', 'Craft and related trades workers (ISCO 08 - 7)', 'Plant and machine operators, and assemblers (ISCO 08 - 8)', 'Elementary occupations (ISCO 08 - 9)']
# [340652.701031629, 1217167.65692784, 3178925.18957974, 3176548.88464978, 3039108.12589133, 4428958.24361962, 394309.174516344, 3406732.9550036, 1445735.18436826, 4319336.99210649]
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
EssentialGer = []
RemoteGer = [] 

EssentialGer = Valueger[0] + Valueger[6] + Valueger[7] + Valueger[8] + Valueger[9] + Valueger[4]
RemoteGer = Valueger[1] + Valueger[2] + Valueger[3]  + Valueger[5]

# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt



objects = ['Essential Services','Remote-work Amenable Jobs']
y_pos = np.arange(len(objects))
performance = [EssentialGer,RemoteGer]

print(performance)

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('# number')
plt.title('Remote-work Amenability of Occupations | Italy')


plt.show()
# Out:
# [12945875.132917652, 12001599.97477698]

# %%
#Republic of Korea

# %%
# Demographics

# %%
demo = pd.read_csv("students_data_UN.csv")

# %%
demo.head()
demo['Country or Area'].unique()
# Out:
# array(['Åland Islands', 'Albania', 'Anguilla', 'Armenia', 'Aruba',
#        'Austria', 'Azerbaijan', 'Bahrain', 'Belarus', 'Belgium', 'Benin',
#        'Bermuda', 'Bolivia (Plurinational State of)', 'Botswana',
#        'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Canada', 'Chile', 'China, Hong Kong SAR',
#        'China, Macao SAR', 'Colombia', 'Cook Islands', 'Costa Rica',
#        'Croatia', 'Cuba', 'Cyprus', 'Czechia',
#        "Democratic People's Republic of Korea", 'Denmark', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'El Salvador', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Fiji', 'Finland', 'France',
#        'French Guiana', 'French Polynesia', 'Germany', 'Ghana', 'Greece',
#        'Guadeloupe', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Hungary',
#        'Indonesia', 'Iran (Islamic Republic of)', 'Iraq', 'Ireland',
#        'Isle of Man', 'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan',
# ...

# %%
Germany = demo.loc[demo['Country or Area'] == "Germany"]
Germany = Germany.loc[demo['Sex'] == "Both Sexes"]
Germany = Germany.loc[demo['Age'] == "Total"]

catg = []
values = []

catg = list(Germany["Functional category"])
vals = list(Germany["Value"])


print(vals)
# Out:
# [37315760.0, 3620290.0, 17347580.0, 16347900.0]

# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


objects = catg
y_pos = np.arange(len(objects))
performance = vals

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('# number')
plt.title('Germany Population')

plt.show()

# %%
Germany = demo.loc[demo['Country or Area'] == "Saudi Arabia"]
Germany = Germany.loc[demo['Sex'] == "Both Sexes"]
Germany = Germany.loc[demo['Age'] == "Total"]

catg = []
values = []

catg = list(Germany["Functional category"])
vals = list(Germany["Value"])


print(vals)
# Out:
# [9324961.0, 4542160.0, 3729874.0, 706090.0, 346837.0]

# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


objects = catg
y_pos = np.arange(len(objects))
performance = vals

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('# number')
plt.title('Saudi Arabia Population')

plt.show()

# %%
Germany = demo.loc[demo['Country or Area'] == "Spain"]
Germany = Germany.loc[demo['Sex'] == "Both Sexes"]
Germany = Germany.loc[demo['Age'] == "Total"]

catg = []
values = []

catg = ['Total','Student','Pension or capital income recipient','Other']
vals = list(Germany["Value"])

vals = [vals[0]+vals[5],vals[1]+vals[6],vals[2]+vals[7],vals[3]+vals[8]]
print(catg)
# Out:
# ['Total', 'Student', 'Pension or capital income recipient', 'Other']

# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


objects = catg
y_pos = np.arange(len(objects))
performance = vals

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('# number')
plt.title('Spain Population')

plt.show()

# %%
Germany = demo.loc[demo['Country or Area'] == "Italy"]
Germany = Germany.loc[demo['Sex'] == "Both Sexes"]
Germany = Germany.loc[demo['Age'] == "Total"]

catg = []
values = []

catg = list(Germany["Functional category"])
vals = list(Germany["Value"])


print(catg)
# Out:
# ['Total', 'Homemaker', 'Student', 'Pension or capital income recipient', 'Other', 'Unknown']

# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


objects = catg
y_pos = np.arange(len(objects))
performance = vals

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('# number')
plt.title('Italy Population')

plt.show()
